# %%
# Importing the Keras libraries and packages
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dropout
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from PIL import Image

# Initialising the CNN
model = Sequential();

#input layer
#Convolution
model.add(Conv2D(32,(3,3),input_shape=(64,64,3), activation='relu'))
#Pooling
model.add(MaxPooling2D(pool_size=(2,2)))

#second layer
model.add(Conv2D(32,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

#third layer
model.add(Conv2D(16,(3,3),input_shape=(64,64,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

#Flattening before going into dense layer
model.add(Flatten())

#Full connection
model.add(Dense(2000, activation='relu'))
model.add(Dropout(0.5))

#another dense layer
model.add(Dense(1000, activation='relu'))
model.add(Dropout(0.5))

#another dense layer
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.5))

#another dense layer
model.add(Dense(250, activation='relu'))

#Adding the Output Layer
model.add(Dense(4, activation='softmax'))

#Compiling the CNN
model.compile(optimizer ='adam',loss='categorical_crossentropy',metrics=['accuracy'])

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('Dataset/train',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')

test_set = test_datagen.flow_from_directory('Dataset/test',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'categorical')

model.fit_generator(training_set,
                         steps_per_epoch = 100,
                         epochs = 40,
                         validation_data = test_set,
                         validation_steps = 50)


# prediction of the image
from tensorflow.keras.preprocessing import image
test_image = image.load_img ('Dataset/single/A.JPG', target_size= (64, 64))
test_image.show()
test_image = image.img_to_array (test_image)
test_image = np.expand_dims(test_image, axis = 0)
results = model.predict(test_image)
training_set.class_indices
if results[0][0] == 1:
    prediction = 'A'
    print(prediction)
elif results[0][1] == 2:
    prediction = 'B'
    print(prediction)
elif results[0][2] == 3:
    prediction = 'C'
    print(prediction)
else:
    prediction = 'D'
    print(prediction)
# Out:
# Found 7771 images belonging to 4 classes.
# Found 1943 images belonging to 4 classes.
# Epoch 1/40
# /tmp/ipykernel_11144/360836204.py:70: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(training_set,
# 2023-05-23 15:18:01.945201: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 100/100 [==============================] - ETA: 0s - loss: 1.3546 - accuracy: 0.2923
# 2023-05-23 15:18:12.722446: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 100/100 [==============================] - 12s 111ms/step - loss: 1.3546 - accuracy: 0.2923 - val_loss: 1.2879 - val_accuracy: 0.3244
# Epoch 2/40
# 100/100 [==============================] - 11s 108ms/step - loss: 0.9789 - accuracy: 0.5706 - val_loss: 0.7498 - val_accuracy: 0.6606
# Epoch 3/40
# 100/100 [==============================] - 11s 108ms/step - loss: 0.7456 - accuracy: 0.6878 - val_loss: 0.6748 - val_accuracy: 0.7294
# Epoch 4/40
# 100/100 [==============================] - 11s 109ms/step - loss: 0.6108 - accuracy: 0.7688 - val_loss: 0.5827 - val_accuracy: 0.7625
# Epoch 5/40
# 100/100 [==============================] - 11s 109ms/step - loss: 0.5135 - accuracy: 0.7991 - val_loss: 0.5582 - val_accuracy: 0.7869
# Epoch 6/40
# 100/100 [==============================] - 11s 109ms/step - loss: 0.4464 - accuracy: 0.8307 - val_loss: 0.4212 - val_accuracy: 0.8350
# Epoch 7/40
# 100/100 [==============================] - 11s 111ms/step - loss: 0.3510 - accuracy: 0.8739 - val_loss: 0.7761 - val_accuracy: 0.7663
# Epoch 8/40
# 100/100 [==============================] - 11s 110ms/step - loss: 0.3452 - accuracy: 0.8687 - val_loss: 0.4795 - val_accuracy: 0.8163
# Epoch 9/40
# 100/100 [==============================] - 11s 109ms/step - loss: 0.3559 - accuracy: 0.8629 - val_loss: 0.5299 - val_accuracy: 0.8281
# Epoch 10/40
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2778 - accuracy: 0.8973 - val_loss: 0.4974 - val_accuracy: 0.8537
# Epoch 11/40
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2995 - accuracy: 0.8925 - val_loss: 0.3035 - val_accuracy: 0.8744
# Epoch 12/40
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2527 - accuracy: 0.9100 - val_loss: 0.2785 - val_accuracy: 0.9144
# Epoch 13/40
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2440 - accuracy: 0.9111 - val_loss: 0.3070 - val_accuracy: 0.9044
# Epoch 14/40
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2356 - accuracy: 0.9166 - val_loss: 0.5045 - val_accuracy: 0.8550
# Epoch 15/40
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2465 - accuracy: 0.9102 - val_loss: 0.3270 - val_accuracy: 0.8806
# Epoch 16/40
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2131 - accuracy: 0.9256 - val_loss: 0.7251 - val_accuracy: 0.7663
# Epoch 17/40
# 100/100 [==============================] - 11s 113ms/step - loss: 0.2356 - accuracy: 0.9156 - val_loss: 0.4188 - val_accuracy: 0.8906
# Epoch 18/40
# 100/100 [==============================] - 11s 113ms/step - loss: 0.1945 - accuracy: 0.9275 - val_loss: 0.2336 - val_accuracy: 0.9200
# Epoch 19/40
# 100/100 [==============================] - 11s 112ms/step - loss: 0.1935 - accuracy: 0.9309 - val_loss: 0.3921 - val_accuracy: 0.8731
# Epoch 20/40
# 100/100 [==============================] - 11s 113ms/step - loss: 0.2157 - accuracy: 0.9231 - val_loss: 0.4151 - val_accuracy: 0.8756
# Epoch 21/40
# 100/100 [==============================] - 11s 113ms/step - loss: 0.2064 - accuracy: 0.9303 - val_loss: 0.1911 - val_accuracy: 0.9356
# Epoch 22/40
# 100/100 [==============================] - 11s 114ms/step - loss: 0.2004 - accuracy: 0.9319 - val_loss: 0.2389 - val_accuracy: 0.9144
# Epoch 23/40
# 100/100 [==============================] - 11s 112ms/step - loss: 0.1715 - accuracy: 0.9441 - val_loss: 0.2980 - val_accuracy: 0.9075
# Epoch 24/40
# 100/100 [==============================] - 11s 112ms/step - loss: 0.2070 - accuracy: 0.9318 - val_loss: 0.1991 - val_accuracy: 0.9325
# Epoch 25/40
# 100/100 [==============================] - 11s 112ms/step - loss: 0.1661 - accuracy: 0.9399 - val_loss: 0.4498 - val_accuracy: 0.8606
# Epoch 26/40
# 100/100 [==============================] - 11s 111ms/step - loss: 0.1579 - accuracy: 0.9441 - val_loss: 0.2046 - val_accuracy: 0.9262
# Epoch 27/40
# 100/100 [==============================] - 11s 111ms/step - loss: 0.1699 - accuracy: 0.9406 - val_loss: 0.2089 - val_accuracy: 0.9287
# Epoch 28/40
# 100/100 [==============================] - 11s 112ms/step - loss: 0.1294 - accuracy: 0.9537 - val_loss: 0.1992 - val_accuracy: 0.9287
# Epoch 29/40
# 100/100 [==============================] - 11s 111ms/step - loss: 0.1630 - accuracy: 0.9443 - val_loss: 0.1622 - val_accuracy: 0.9431
# Epoch 30/40
# 100/100 [==============================] - 11s 113ms/step - loss: 0.1642 - accuracy: 0.9463 - val_loss: 0.2018 - val_accuracy: 0.9381
# Epoch 31/40
# 100/100 [==============================] - 11s 114ms/step - loss: 0.1536 - accuracy: 0.9496 - val_loss: 0.3222 - val_accuracy: 0.9125
# Epoch 32/40
# 100/100 [==============================] - 11s 112ms/step - loss: 0.1331 - accuracy: 0.9571 - val_loss: 0.1502 - val_accuracy: 0.9488
# Epoch 33/40
# 100/100 [==============================] - 11s 114ms/step - loss: 0.1155 - accuracy: 0.9634 - val_loss: 0.1822 - val_accuracy: 0.9337
# Epoch 34/40
# 100/100 [==============================] - 11s 112ms/step - loss: 0.1324 - accuracy: 0.9541 - val_loss: 0.3057 - val_accuracy: 0.9150
# Epoch 35/40
# 100/100 [==============================] - 11s 112ms/step - loss: 0.1422 - accuracy: 0.9534 - val_loss: 0.1681 - val_accuracy: 0.9425
# Epoch 36/40
# 100/100 [==============================] - 11s 113ms/step - loss: 0.1204 - accuracy: 0.9593 - val_loss: 0.1405 - val_accuracy: 0.9588
# Epoch 37/40
# 100/100 [==============================] - 11s 111ms/step - loss: 0.1217 - accuracy: 0.9594 - val_loss: 0.0957 - val_accuracy: 0.9669
# Epoch 38/40
# 100/100 [==============================] - 11s 113ms/step - loss: 0.0923 - accuracy: 0.9647 - val_loss: 0.1614 - val_accuracy: 0.9544
# Epoch 39/40
# 100/100 [==============================] - 11s 113ms/step - loss: 0.1126 - accuracy: 0.9603 - val_loss: 0.1453 - val_accuracy: 0.9494
# Epoch 40/40
# 100/100 [==============================] - 11s 113ms/step - loss: 0.1388 - accuracy: 0.9509 - val_loss: 0.2632 - val_accuracy: 0.9169
# 1/1 [==============================] - 0s 83ms/step
# D
